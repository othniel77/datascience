# %% [markdown]
# <a href="https://colab.research.google.com/github/othniel77/datascience/blob/main/Fusion_des_donn%C3%A9es_ordonn%C3%A9es_et_de_s%C3%A9ries_temporelles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-3aa286c8-c5be-431b-847c-f674ca660262" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3aa286c8-c5be-431b-847c-f674ca660262">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gdp = pd.read_csv('/content/WorldBank_GDP (2).csv')
print(gdp.head())
print(gdp.shape)
# Out:
#     Country Name Country Code     Indicator Name  Year           GDP
# 0          China          CHN  GDP (current US$)  2010  6.087160e+12
# 1        Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2          Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3  United States          USA  GDP (current US$)  2010  1.499210e+13
# 4          China          CHN  GDP (current US$)  2011  7.551500e+12
# (40, 5)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    40 non-null     object
#  1   Country Code    40 non-null     object
#  2   Indicator Name  40 non-null     object
#  3   Year            40 non-null     int64
#  4   GDP             40 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.7+ KB

# %%
sp500 = pd.read_csv('/content/S&P500.csv')
print(sp500.head())
print(sp500.shape)
# Out:
#    Date  Returns
# 0  2008   -38.49
# 1  2009    23.45
# 2  2010    12.78
# 3  2011     0.00
# 4  2012    13.41
# (10, 2)

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     10 non-null     int64
#  1   Returns  10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 288.0 bytes

# %%
# Use merge_ordered() to merge gdp and sp500 on year and date
gdp_sp500 = pd.merge_ordered(gdp, sp500, left_on='Year', right_on='Date',
                             how='left')

# Print gdp_sp500
print(gdp_sp500)
# Out:
#      Country Name Country Code     Indicator Name  Year           GDP    Date  \
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12  2010.0
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12  2010.0
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12  2010.0
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13  2010.0
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12  2011.0
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12  2011.0
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12  2011.0
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13  2011.0
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12  2012.0
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12  2012.0
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12  2012.0
# ...

# %% [markdown]
# use the function's ability to interpolate missing data to forward fill the missing value for returns, assigning this table to the variable gdp_sp500.

# %%
# Use merge_ordered() to merge gdp and sp500, interpolate missing value
gdp_sp500 = pd.merge_ordered(gdp, sp500, left_on='Year', right_on='Date',
                             how='left',  fill_method='ffill')

# Print gdp_sp500
print (gdp_sp500)
# Out:
#      Country Name Country Code     Indicator Name  Year           GDP  Date  \
# 0           China          CHN  GDP (current US$)  2010  6.087160e+12  2010
# 1         Germany          DEU  GDP (current US$)  2010  3.417090e+12  2010
# 2           Japan          JPN  GDP (current US$)  2010  5.700100e+12  2010
# 3   United States          USA  GDP (current US$)  2010  1.499210e+13  2010
# 4           China          CHN  GDP (current US$)  2011  7.551500e+12  2011
# 5         Germany          DEU  GDP (current US$)  2011  3.757700e+12  2011
# 6           Japan          JPN  GDP (current US$)  2011  6.157460e+12  2011
# 7   United States          USA  GDP (current US$)  2011  1.554260e+13  2011
# 8           China          CHN  GDP (current US$)  2012  8.532230e+12  2012
# 9         Germany          DEU  GDP (current US$)  2012  3.543980e+12  2012
# 10          Japan          JPN  GDP (current US$)  2012  6.203210e+12  2012
# ...

# %%
gdp_sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    40 non-null     object
#  1   Country Code    40 non-null     object
#  2   Indicator Name  40 non-null     object
#  3   Year            40 non-null     int64
#  4   GDP             40 non-null     float64
#  5   Date            40 non-null     int64
#  6   Returns         40 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.5+ KB

# %% [markdown]
# Print the correlation matrix of the gdp_returns table using the .corr() method.

# %%
# Use merge_ordered() to merge gdp and sp500, interpolate missing value
gdp_sp500 = pd.merge_ordered(gdp, sp500, left_on='Year', right_on='Date',
                             how='left',  fill_method='ffill')

# Subset the gdp and returns columns
gdp_returns = gdp_sp500[['GDP','Returns']]

# Print gdp_returns correlation
print (gdp_returns.corr())
# Out:
#               GDP   Returns
# GDP      1.000000  0.040669
# Returns  0.040669  1.000000

# %% [markdown]
# Finally, the correlation of 0.049 between the GDP and S&P500 is low to moderate at best. You may want to find another predictor if you plan to play in the stock market.

# %% [markdown]
# ## Merge_asof()

# %%
visa = gdp
print(gdp.head())
# Out:
#     Country Name Country Code     Indicator Name  Year           GDP
# 0          China          CHN  GDP (current US$)  2010  6.087160e+12
# 1        Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2          Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3  United States          USA  GDP (current US$)  2010  1.499210e+13
# 4          China          CHN  GDP (current US$)  2011  7.551500e+12

# %%
ibm = pd.read_csv('/content/WorldBank_POP (1).csv')
print(ibm.head())
# Out:
#   Country Name Country Code     Indicator Name  Year         Pop
# 0        Aruba          ABW  Population, total  2010    101669.0
# 1  Afghanistan          AFG  Population, total  2010  29185507.0
# 2       Angola          AGO  Population, total  2010  23356246.0
# 3      Albania          ALB  Population, total  2010   2913021.0
# 4      Andorra          AND  Population, total  2010     84449.0

# %%
pd.merge_asof(visa, ibm, on='Year',suffixes=('_gdp','_pop'))
# Out:
#    Country Name_gdp Country Code_gdp Indicator Name_gdp  Year           GDP  \
# 0             China              CHN  GDP (current US$)  2010  6.087160e+12
# 1           Germany              DEU  GDP (current US$)  2010  3.417090e+12
# 2             Japan              JPN  GDP (current US$)  2010  5.700100e+12
# 3     United States              USA  GDP (current US$)  2010  1.499210e+13
# 4             China              CHN  GDP (current US$)  2011  7.551500e+12
# 5           Germany              DEU  GDP (current US$)  2011  3.757700e+12
# 6             Japan              JPN  GDP (current US$)  2011  6.157460e+12
# 7     United States              USA  GDP (current US$)  2011  1.554260e+13
# 8             China              CHN  GDP (current US$)  2012  8.532230e+12
# 9           Germany              DEU  GDP (current US$)  2012  3.543980e+12
# 10            Japan              JPN  GDP (current US$)  2012  6.203210e+12
# ...

# %%
pd.merge_asof(visa, ibm, on=['Year'],suffixes=('_gdp','_pop'),direction='forward')
# Out:
#    Country Name_gdp Country Code_gdp Indicator Name_gdp  Year           GDP  \
# 0             China              CHN  GDP (current US$)  2010  6.087160e+12
# 1           Germany              DEU  GDP (current US$)  2010  3.417090e+12
# 2             Japan              JPN  GDP (current US$)  2010  5.700100e+12
# 3     United States              USA  GDP (current US$)  2010  1.499210e+13
# 4             China              CHN  GDP (current US$)  2011  7.551500e+12
# 5           Germany              DEU  GDP (current US$)  2011  3.757700e+12
# 6             Japan              JPN  GDP (current US$)  2011  6.157460e+12
# 7     United States              USA  GDP (current US$)  2011  1.554260e+13
# 8             China              CHN  GDP (current US$)  2012  8.532230e+12
# 9           Germany              DEU  GDP (current US$)  2012  3.543980e+12
# 10            Japan              JPN  GDP (current US$)  2012  6.203210e+12
# ...

# %%
visa = gdp
print(visa.head())
# Out:
#     Country Name Country Code     Indicator Name  Year           GDP
# 0          China          CHN  GDP (current US$)  2010  6.087160e+12
# 1        Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 2          Japan          JPN  GDP (current US$)  2010  5.700100e+12
# 3  United States          USA  GDP (current US$)  2010  1.499210e+13
# 4          China          CHN  GDP (current US$)  2011  7.551500e+12

# %%
ibm = ibm
print(ibm.head())
# Out:
#   Country Name Country Code     Indicator Name  Year         Pop
# 0        Aruba          ABW  Population, total  2010    101669.0
# 1  Afghanistan          AFG  Population, total  2010  29185507.0
# 2       Angola          AGO  Population, total  2010  23356246.0
# 3      Albania          ALB  Population, total  2010   2913021.0
# 4      Andorra          AND  Population, total  2010     84449.0

# %% [markdown]
# # Selection des données avec .query()

# %%
gdp = visa

# %%
pop = ibm

# %%
# Merge gdp and pop on date and country with fill
gdp_pop = pd.merge_ordered(gdp,pop,on =['Country Name','Year'],fill_method = 'ffill')

# %%
# Add a column named gdp_per_capita to gdp_pop that divides the gdp by pop
gdp_pop['gdp_per_capita'] = gdp_pop['GDP']/gdp_pop['Pop']

# %%
# Pivot table of gdp_per_capita, where index is date and columns is country
gdp_pivot = gdp_pop.pivot_table('gdp_per_capita', index = 'Year', columns ='Country Name')

# %%
import matplotlib.pyplot as plt

# %%
# Select dates equal to or greater than 2017
recent_gdp_pop = gdp_pivot.query('Year >= 2018')
recent_gdp_pop

# Plot recent_gdp_pop
#recent_gdp_pop.plot(rot=90)
#plt.show()
# Out:
# Country Name       China       Colombia       Comoros  Congo, Dem. Rep.  \
# Year
# 2018          9770.88165  274089.837425  1.634968e+07     161871.167028
#
# Country Name   Congo, Rep.    Costa Rica  Cote d'Ivoire       Croatia  \
# Year
# 2018          2.594824e+06  2.721944e+06   542824.83119  3.327676e+06
#
# Country Name          Cuba       Curacao  ...     Uzbekistan       Vanuatu  \
# Year                                      ...
# 2018          1.200215e+06  8.513159e+07  ...  621873.805203  7.002221e+07
#
# Country Name  Venezuela, RB        Vietnam  Virgin Islands (U.S.)  \
# Year
# 2018          709870.508322  214507.172594           1.915748e+08
#
# Country Name  West Bank and Gaza        World    Yemen, Rep.        Zambia  \
# Year
# 2018                4.485382e+06  2698.626601  719124.358256  1.181092e+06
#
# Country Name      Zimbabwe
# Year
# 2018          1.419356e+06
#
# [1 rows x 219 columns]

# %% [markdown]
# You can see from the plot that the per capita GDP of Australia passed Sweden in 1992

# %%
ratings = pd.read_pickle('/content/ratings.p')
print(ratings.head())
# Out:
#        id  vote_average  vote_count
# 0   19995           7.2     11800.0
# 1     285           6.9      4500.0
# 2  206647           6.3      4466.0
# 3   49026           7.6      9106.0
# 4   49529           6.1      2124.0

# %%
ratings.query('vote_count >= 9000')
# Out:
#          id  vote_average  vote_count
# 0     19995           7.2     11800.0
# 3     49026           7.6      9106.0
# 16    24428           7.4     11776.0
# 65      155           8.2     12002.0
# 94   118340           7.9      9742.0
# 95   157336           8.1     10867.0
# 96    27205           8.1     13752.0
# 127   76341           7.2      9427.0
# 287   68718           7.8     10099.0
# 426   70160           6.9      9455.0
# 662     550           8.3      9413.0
# 788  293660           7.4     10995.0

# %%
ratings.query('vote_count > 9000 and vote_average < 7.5')
# Out:
#          id  vote_average  vote_count
# 0     19995           7.2     11800.0
# 16    24428           7.4     11776.0
# 127   76341           7.2      9427.0
# 426   70160           6.9      9455.0
# 788  293660           7.4     10995.0

# %%
ratings.query('vote_count > 9000 or vote_average < 7.5')
# Out:
#           id  vote_average  vote_count
# 0      19995           7.2     11800.0
# 1        285           6.9      4500.0
# 2     206647           6.3      4466.0
# 3      49026           7.6      9106.0
# 4      49529           6.1      2124.0
# ...      ...           ...         ...
# 4798    9367           6.6       238.0
# 4799   72766           5.9         5.0
# 4800  231617           7.0         6.0
# 4801  126186           5.7         7.0
# 4802   25975           6.3        16.0
#
# [4473 rows x 3 columns]

# %% [markdown]
# ## Reshaping data with .melt()

# %%
gdp_pop.head()
# Out:
#   Country Name Country Code_x Indicator Name_x  Year  GDP Country Code_y  \
# 0  Afghanistan            NaN              NaN  2010  NaN            AFG
# 1  Afghanistan            NaN              NaN  2011  NaN            AFG
# 2  Afghanistan            NaN              NaN  2012  NaN            AFG
# 3  Afghanistan            NaN              NaN  2012  NaN            AFG
# 4  Afghanistan            NaN              NaN  2013  NaN            AFG
#
#     Indicator Name_y         Pop  gdp_per_capita
# 0  Population, total  29185507.0             NaN
# 1  Population, total  30117413.0             NaN
# 2  Population, total  31161376.0             NaN
# 3  Population, total  31161376.0             NaN
# 4  Population, total  32269589.0             NaN

# %%
ratings_tall = ratings.melt(id_vars=['id'])
print(ratings_tall.head(10))
# Out:
#        id      variable  value
# 0   19995  vote_average    7.2
# 1     285  vote_average    6.9
# 2  206647  vote_average    6.3
# 3   49026  vote_average    7.6
# 4   49529  vote_average    6.1
# 5     559  vote_average    5.9
# 6   38757  vote_average    7.4
# 7   99861  vote_average    7.3
# 8     767  vote_average    7.4
# 9  209112  vote_average    5.7

# %%
ratings_tall = ratings.melt(id_vars=['id'],value_vars=['vote_count'])
print(ratings_tall.head())
# Out:
#        id    variable    value
# 0   19995  vote_count  11800.0
# 1     285  vote_count   4500.0
# 2  206647  vote_count   4466.0
# 3   49026  vote_count   9106.0
# 4   49529  vote_count   2124.0

# %%
ratings_tall = ratings.melt(id_vars=['id'],value_vars=['vote_count'],var_name=['variable_selectionné'], value_name='le nombre')
print(ratings_tall.head(8))
# Out:
#        id variable_selectionné  le nombre
# 0   19995           vote_count    11800.0
# 1     285           vote_count     4500.0
# 2  206647           vote_count     4466.0
# 3   49026           vote_count     9106.0
# 4   49529           vote_count     2124.0
# 5     559           vote_count     3576.0
# 6   38757           vote_count     3330.0
# 7   99861           vote_count     6767.0

# %% [markdown]
# # **Course wrap-up**

# %% [markdown]
# c'est fini
